# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from scipy import stats
import statsmodels.api as sm
import seaborn as sns

# %%
people = pd.read_csv("income.data.csv")
people.head()
# Out:
#    Unnamed: 0    income  happiness
# 0           1  3.862647   2.314489
# 1           2  4.979381   3.433490
# 2           3  4.923957   4.599373
# 3           4  3.214372   2.791114
# 4           5  7.196409   5.596398

# %%
people_final = people.dropna()
people_final.reset_index(inplace=True, drop = True)

# %%
people_final
# Out:
#      Unnamed: 0    income  happiness
# 0             1  3.862647   2.314489
# 1             2  4.979381   3.433490
# 2             3  4.923957   4.599373
# 3             4  3.214372   2.791114
# 4             5  7.196409   5.596398
# ..          ...       ...        ...
# 493         494  5.249209   4.568705
# 494         495  3.471799   2.535002
# 495         496  6.087610   4.397451
# 496         497  3.440847   2.070664
# 497         498  4.530545   3.710193
#
# [498 rows x 3 columns]

# %%
sns.pairplot(people_final)

# %%
people_final.columns
# Out:
# Index(['Unnamed: 0', 'income', 'happiness'], dtype='object')

# %%
old_data = people_final[["income","happiness"]]

# %%
old_formula='happiness ~ income'

# %%
from statsmodels.formula.api import ols

# %%
OLS = ols(formula =old_formula, data = old_data)
model =OLS.fit()

# %%
model.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:              happiness   R-squared:                       0.749
# Model:                            OLS   Adj. R-squared:                  0.749
# Method:                 Least Squares   F-statistic:                     1483.
# Date:                Wed, 18 Sep 2024   Prob (F-statistic):          3.96e-151
# Time:                        07:59:51   Log-Likelihood:                -540.72
# No. Observations:                 498   AIC:                             1085.
# Df Residuals:                     496   BIC:                             1094.
# Df Model:                           1
# Covariance Type:            nonrobust
# ...
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# Intercept      0.2043      0.089      2.299      0.022       0.030       0.379
# ...

# %%
sns.regplot(x='income', y='happiness', data =old_data )
# Out:
# <Axes: xlabel='income', ylabel='happiness'>
